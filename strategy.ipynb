# %%
from vtrade import vTrade
# import plotly.io as pio
# pio.renderers.default = 'notebook_connected'

MA_types = ["SMA", "EWM"]
vtr = vTrade()

# %%
df = vtr.calc_MA("AAPL", 20, 100, MA_types)
df
# Out:
# shape: (755, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ datetime  ┆ open      ┆ high      ┆ low       ┆ … ┆ SMA_20    ┆ SMA_100   ┆ EWM_20    ┆ EWM_100  │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ date      ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2021-11-0 ┆ 150.2     ┆ 151.42999 ┆ 150.06    ┆ … ┆ null      ┆ null      ┆ 151.42999 ┆ 151.4299 │
# │ 9         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 9        │
# │ 2021-11-1 ┆ 150.02    ┆ 150.13    ┆ 147.85001 ┆ … ┆ null      ┆ null      ┆ 150.74749 ┆ 150.7734 │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆ 95       │
# ...

# %%
vtr.show_MA(df, MA_types)
# Out:
# /home/viettr/Desktop/Dev/vtrade/vtrade_venv/lib/python3.11/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
