# %%
from vtrade import vTrade
from strategy import Strategy
# import plotly.io as pio
# pio.renderers.default = 'notebook_connected'

SHORT_MA = "EWM_20"
LONG_MA = "EWM_50"
vtr = vTrade()
df = vtr.get_stock_data("COIN")

# %%
strategy = Strategy()
df = strategy.calc_MA(df, SHORT_MA)
df = strategy.calc_MA(df, LONG_MA)
# Out:
# 2025-02-15 12:06:36.303 | INFO     | strategy:calc_MA:38 - EWM is calculated
# 2025-02-15 12:06:36.305 | INFO     | utils.utils:wrapper:11 - calc_MA took 0.0019788742065429688s
# 2025-02-15 12:06:36.306 | INFO     | strategy:calc_MA:38 - EWM is calculated
# 2025-02-15 12:06:36.307 | INFO     | utils.utils:wrapper:11 - calc_MA took 0.0014998912811279297s

# %%
df_ma = strategy.calc_crossing_MA(df, SHORT_MA, LONG_MA)
strategy.show_crossing_MA(df_ma, SHORT_MA, LONG_MA)
# Out:
# 2025-02-15 12:06:36.318 | INFO     | strategy:calc_crossing_MA:59 - Calculated crossing MA points
# 2025-02-15 12:06:36.320 | INFO     | strategy:calc_crossing_MA:60 - Sell-buy signal for crossing MA is generated
# 2025-02-15 12:06:36.320 | INFO     | utils.utils:wrapper:11 - calc_crossing_MA took 0.003720521926879883s
# /home/viettr/Desktop/Dev/vtrade/vtrade_venv/lib/python3.11/site-packages/plotly/graph_objs/_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
df_rsi = strategy.calc_RSI(df)
strategy.show_RSI(df_rsi)
# Out:
# 2025-02-15 12:06:36.510 | INFO     | strategy:calc_RSI:160 - Calculated RSI
# 2025-02-15 12:06:36.511 | INFO     | strategy:calc_RSI:169 - Sell-buy signal for RSI is generated
# 2025-02-15 12:06:36.512 | INFO     | utils.utils:wrapper:11 - calc_RSI took 0.0043392181396484375s

# %%
df_bb = strategy.calc_bollinger_bands(df)
strategy.show_bollinger_bands(df_bb)
# Out:
# 2025-02-15 12:06:36.587 | INFO     | strategy:calc_MA:32 - SMA is calculated
# 2025-02-15 12:06:36.589 | INFO     | utils.utils:wrapper:11 - calc_MA took 0.0026810169219970703s
# 2025-02-15 12:06:36.594 | INFO     | utils.utils:wrapper:11 - calc_bollinger_bands took 0.0076143741607666016s
