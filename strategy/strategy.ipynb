# %%
from utils.vtrade import vTrade
from crossing_ma import StrategyCrossingMA
# import plotly.io as pio
# pio.renderers.default = 'notebook_connected'

SHORT_MA = 50
LONG_MA = 200
SYMBOL = "COIN"
vtr = vTrade()
resp = await vtr.get_stocks_async([SYMBOL])
df = resp[SYMBOL]
# Out:
# 2025-03-07 22:16:56.873 | DEBUG    | utils.vtrade:get_stocks_async:23 - Fetching ['COIN'] data
# 2025-03-07 22:16:57.029 | DEBUG    | utils.vtrade:__fetch_stock_data:39 - Received response when fetch COIN data

# %%
x_ma = StrategyCrossingMA()
df_ma = x_ma.calc_MA(df, SHORT_MA)
df_ma = x_ma.calc_MA(df, LONG_MA)
# Out:
# 2025-03-07 22:16:57.066 | INFO     | crossing_ma:calc_MA:31 - SMA is calculated
# 2025-03-07 22:16:57.067 | INFO     | utils.utils:wrapper:21 - calc_MA took 0.0016307830810546875s
# 2025-03-07 22:16:57.068 | INFO     | crossing_ma:calc_MA:31 - SMA is calculated
# 2025-03-07 22:16:57.069 | INFO     | utils.utils:wrapper:21 - calc_MA took 0.001176595687866211s

# %%
df_ma = x_ma.execute(df, SHORT_MA, LONG_MA)
x_ma.show(df_ma, SHORT_MA, LONG_MA)
# Out:
# 2025-03-07 22:16:57.077 | INFO     | crossing_ma:calc_MA:31 - SMA is calculated
# 2025-03-07 22:16:57.078 | INFO     | utils.utils:wrapper:21 - calc_MA took 0.001878499984741211s
# 2025-03-07 22:16:57.079 | INFO     | crossing_ma:calc_MA:31 - SMA is calculated
# 2025-03-07 22:16:57.081 | INFO     | utils.utils:wrapper:21 - calc_MA took 0.001859426498413086s
# 2025-03-07 22:16:57.084 | INFO     | crossing_ma:execute:74 - Sell-buy signal for crossing MA is generated
# 2025-03-07 22:16:57.087 | INFO     | utils.utils:wrapper:21 - execute took 0.010935783386230469s

# %%
from rsi import StrategyRSI

str_rsi = StrategyRSI()
df_rsi = str_rsi.execute(df)
str_rsi.show(df_rsi)
# Out:
# 2025-03-07 22:16:57.601 | INFO     | rsi:calc_RSI:55 - Calculated RSI: P14
# 2025-03-07 22:16:57.602 | INFO     | utils.utils:wrapper:21 - calc_RSI took 0.0032758712768554688s
# 2025-03-07 22:16:57.603 | INFO     | rsi:execute:85 - Sell-buy signal for rsi is generated

# %%
from bollinger_bands import StrategyBollingerBands

str_bb = StrategyBollingerBands()
df_bb = str_bb.execute(df)
str_bb.show(df_bb)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from bollinger_bands import StrategyBollingerBands
#       3 str_bb = StrategyBollingerBands()
#       4 df_bb = str_bb.execute(df)
#
# File ~/Desktop/Dev/vTrade/strategy/bollinger_bands.py:4
#       2 from utils import *
#       3 from strategy import Strategy
# ----> 4 from strategy.crossing_ma import StrategyCrossingMA
#       6 class StrategyBollingerBands(Strategy):
#       7     def __init__(self, moving_avg: int=20, standard_deviation: int=2):
#
# ModuleNotFoundError: No module named 'strategy.crossing_ma'; 'strategy' is not a package
