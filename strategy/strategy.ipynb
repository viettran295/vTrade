# %%
from vtrade import vTrade
from crossing_ma import StrategyCrossingMA
# import plotly.io as pio
# pio.renderers.default = 'notebook_connected'

SHORT_MA = 50
LONG_MA = 200
SYMBOL = "COIN"
vtr = vTrade()
resp = await vtr.get_stocks_async([SYMBOL])
df = resp[SYMBOL]
# Out:
# 2025-03-06 22:31:29.468 | DEBUG    | vtrade:get_stocks_async:23 - Fetching ['COIN'] data
# 2025-03-06 22:31:29.584 | DEBUG    | vtrade:__fetch_stock_data:39 - Received response when fetch COIN data

# %%
x_ma = StrategyCrossingMA()
df_ma = x_ma.calc_MA(df, SHORT_MA)
df_ma = x_ma.calc_MA(df, LONG_MA)
# Out:
# 2025-03-06 22:31:29.604 | INFO     | crossing_ma:calc_MA:31 - SMA is calculated
# 2025-03-06 22:31:29.606 | INFO     | utils.utils:wrapper:21 - calc_MA took 0.002602100372314453s
# 2025-03-06 22:31:29.608 | INFO     | crossing_ma:calc_MA:31 - SMA is calculated
# 2025-03-06 22:31:29.609 | INFO     | utils.utils:wrapper:21 - calc_MA took 0.0012879371643066406s

# %%
df_ma = x_ma.execute(df, SHORT_MA, LONG_MA)
x_ma.show(df_ma, SHORT_MA, LONG_MA)
# Out:
# 2025-03-06 22:31:29.670 | INFO     | crossing_ma:calc_MA:31 - SMA is calculated
# 2025-03-06 22:31:29.672 | INFO     | utils.utils:wrapper:21 - calc_MA took 0.001961946487426758s
# 2025-03-06 22:31:29.673 | INFO     | crossing_ma:calc_MA:31 - SMA is calculated
# 2025-03-06 22:31:29.674 | INFO     | utils.utils:wrapper:21 - calc_MA took 0.0012941360473632812s
# 2025-03-06 22:31:29.677 | INFO     | crossing_ma:execute:74 - Sell-buy signal for crossing MA is generated
# 2025-03-06 22:31:29.677 | INFO     | utils.utils:wrapper:21 - execute took 0.007448434829711914s

# %%
from rsi import StrategyRSI

str_rsi = StrategyRSI()
df_rsi = str_rsi.execute(df)
str_rsi.show(df_rsi)
# Out:
# 2025-03-06 22:31:29.841 | INFO     | rsi:calc_RSI:55 - Calculated RSI: P14
# 2025-03-06 22:31:29.842 | INFO     | utils.utils:wrapper:21 - calc_RSI took 0.006112337112426758s
# 2025-03-06 22:31:29.844 | INFO     | rsi:execute:85 - Sell-buy signal for rsi is generated

# %%
from bollinger_bands import StrategyBollingerBands

str_bb = StrategyBollingerBands()
df_bb = str_bb.execute(df)
str_bb.show(df_bb)
# Out:
# 2025-03-06 22:31:29.946 | INFO     | crossing_ma:calc_MA:31 - SMA is calculated
# 2025-03-06 22:31:29.948 | INFO     | utils.utils:wrapper:21 - calc_MA took 0.0016217231750488281s
# 2025-03-06 22:31:29.951 | INFO     | utils.utils:wrapper:21 - execute took 0.004868507385253906s
